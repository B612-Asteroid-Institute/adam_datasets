# %%
import pandas as pd
import numpy as np
import os
pd.set_option("display.max_columns", None)
import glob

from astroquery.sdss import SDSS, Conf
from astropy.config import set_temp_cache
from astropy.utils.data import clear_download_cache
from astropy.time import Time

# %%
DATA_DIR = '/astro/store/epyc3/data3/adam_datasets/sdss_dr9_all'

# %%
#filter to a tenth of a RA degree

#rework to include all bands - use pandas magic (split col into rows (pd.explode)) and then set obs_id to obs_id_(band)
ras = np.linspace(0, 360, 360 * 10 + 1)

#checks only photoobj - use photoobjall table to gather all photometric observations? try to check all bands instead of one?
def query_by_ra(ra_start, ra_stop, check_download_integrity=False):
    file_name = os.path.join(DATA_DIR, f"sdss_dr9_observations_{ra_start:06.2f}_{ra_stop:06.2f}_all.csv")
    
    if not os.path.exists(file_name):
        print(ra_start, ra_stop)
        query = f"""
                SELECT objID, fieldID, field, ra, dec, raErr, decErr, 
                u, err_u, TAI_u, 
                g, err_g, TAI_g, 
                r, err_r, TAI_r, 
                i, err_i, TAI_i,
                z, err_z, TAI_z
                FROM PhotoObj
                WHERE (ra >= {ra_start}) AND (ra < {ra_stop}) 
                """
        raw_data = SDSS.query_sql(query, timeout=3600, data_release=9).to_pandas()
        
        #formatted_data = {
        #                    'obs_id':raw_data['objID'].astype(str), # add _filter to tag
        #                    'exposure_id':raw_data['fieldID'].astype(str),
        #                    'mjd_utc':raw_data['TAI_i']/(24*3600),
        #                    'ra':raw_data['ra'],
        #                    'dec':raw_data['dec'],
        #                    'ra_sigma':raw_data['raErr'],
        #                    'dec_sigma':raw_data['decErr'],
        #                    'filter':'i',
        #                    'mag':raw_data['i'],
        #                    'mag_sigma':raw_data['err_i'],
        #                    'observatory_code':'645'
        #                }
        
        

        filters = ['u', 'g', 'r', 'i', 'z']
        columns = ['ra', 'dec', 'fieldID', 'objID', 'raErr', 'decErr', 'obs']
        df_list = []
        for f in filters:
            df = pd.DataFrame(columns=['obs_id', 'ra', 'dec', 'ra_sigma', 'dec_sigma', 
                                       'mag', 'mag_sigma', 'filter', 'observatory_code'])

            df['obs_id'] = raw_data['objID'].apply(lambda x: f'{x}_{f}')
            df['exposure_id'] = raw_data['fieldID']
            df['ra'] = raw_data['ra']
            df['ra_sigma'] = raw_data['raErr']
            df['dec'] = raw_data['dec']
            df['dec_sigma'] = raw_data['decErr']
            df['filter'] = f
            df['mag'] = raw_data[f]
            df['mag_sigma'] = raw_data[f'err_{f}']
            df['mjd_utc'] = Time(raw_data[f'TAI_{f}']/(24*3600), scale='tai', format='mjd').utc.mjd
            df['observatory_code'] = '645'
            df_list.append(df)

        df = pd.concat(df_list, ignore_index=True)
        print(f'before: {len(df)}')
        df = df[df['mag'] != -9999]
        print(f'after: {len(df)}')
        df.sort_values(by=['mjd_utc', 'exposure_id'], ignore_index=True)

        #results = pd.DataFrame(formatted_data)
        #results.to_csv(file_name, index=False)
        df.to_csv(file_name, index=False)
        clear_download_cache(pkgname='astropy')
        
        
    if check_download_integrity:

        downloaded_results = pd.read_csv(file_name, index_col=False)

        query = f"""
                SELECT COUNT(*) AS COUNT
                FROM PhotoObj
                WHERE (ra >= {ra_start}) AND (ra < {ra_stop})
                """
        results = SDSS.query_sql(query, timeout=3600, data_release=9)
        #print(results)

        n_results = results["COUNT"][0]
        n_downloaded_results = len(downloaded_results)

        if n_results != n_downloaded_results:
            err = (f"Downloaded file ({file_name}) contains {n_results} rows while query expected {n_downloaded_results} rows.")
            raise ValueError(err)

# %%
ra_start = 0
ra_stop = .1
#query_by_ra(ra_start, ra_stop)
query = f"""
                SELECT TOP 10 objID, fieldID, field, ra, dec, raErr, decErr, i, err_i, TAI_i, u, err_u, TAI_u, g, err_g, TAI_g
                FROM PhotoObj
                WHERE (ra >= {ra_start}) AND (ra < {ra_stop}) AND i != -9999
        """
raw_data = SDSS.query_sql(query, timeout=3600, data_release=9).to_pandas()

#df = pd.read_csv(os.path.join(DATA_DIR, f"sdss_dr9_observations_{ra_start:06.2f}_{ra_stop:06.2f}.csv"))

# %%
query_by_ra(0, .1)
# Out:
# 0 0.1
# before: 1254705
# after: 1254616

# %%
df = pd.read_csv(os.path.join(DATA_DIR, f"sdss_dr9_observations_{ra_start:06.2f}_{ra_stop:06.2f}_all.csv"))

# %%
df['mjd_utc'].max() - df['mjd_utc'].min()
# Out:
# 4077.000196759269

# %%
raw_data
# Out:
#                       objID              fieldID  field        ra        dec  \
# 0       1237645876871561233  1237645876871561216    168  0.030843  -0.906976
# 1       1237645876871561348  1237645876871561216    168  0.030787  -0.855554
# 2       1237645876871561516  1237645876871561216    168  0.029963  -1.010292
# 3       1237645876871561575  1237645876871561216    168  0.076610  -1.028193
# 4       1237645876871561576  1237645876871561216    168  0.077022  -0.986582
# ...                     ...                  ...    ...       ...        ...
# 250919  1237680512016252950  1237680512016252928     39  0.081647  34.243627
# 250920  1237680512016253546  1237680512016252928     39  0.081656  34.130768
# 250921  1237680512016253987  1237680512016252928     39  0.081701  34.083480
# 250922  1237680512553124114  1237680512553123840     39  0.081744  34.664146
# 250923  1237680512553124517  1237680512553123840     39  0.081718  34.526817
#
#            raErr    decErr          i     err_i         TAI_i          u  \
# 0       0.066555  0.083157  20.235672  0.049130  4.412906e+09  24.106367
# 1       0.015622  0.013614  18.512777  0.012075  4.412906e+09  24.556908
# 2       0.208353  0.112413  20.370285  0.085961  4.412906e+09  22.791155
# 3       0.049008  0.061250  19.716581  0.040413  4.412906e+09  22.938829
# 4       0.030046  0.022980  19.460522  0.025044  4.412906e+09  23.513395
# ...          ...       ...        ...       ...           ...        ...
# 250919  0.100617  0.107357  21.217854  0.111191  4.765158e+09  23.961412
# 250920  0.053586  0.063756  19.941610  0.036617  4.765158e+09  26.169519
# 250921  0.133191  0.145758  21.581175  0.159961  4.765158e+09  23.093163
# 250922  0.008183  0.008556  18.027143  0.008862  4.765158e+09  25.195864
# 250923  0.034967  0.037340  19.690176  0.029969  4.765158e+09  25.104828
#
#            err_u         TAI_u          g     err_g         TAI_g
# 0       1.033302  4.412906e+09  23.350119  0.327600  4.412906e+09
# 1       1.083104  4.412906e+09  21.087315  0.044674  4.412906e+09
# 2       0.594999  4.412906e+09  21.964983  0.149627  4.412906e+09
# 3       0.579495  4.412906e+09  21.498795  0.081531  4.412906e+09
# 4       0.712944  4.412906e+09  21.640930  0.072776  4.412906e+09
# ...          ...           ...        ...       ...           ...
# 250919  1.420360  4.765158e+09  23.467527  0.340532  4.765159e+09
# 250920  0.759941  4.765158e+09  22.433836  0.138546  4.765159e+09
# 250921  0.831049  4.765158e+09  23.263212  0.287414  4.765159e+09
# 250922  1.380749  4.765158e+09  19.822149  0.017225  4.765159e+09
# 250923  1.478262  4.765158e+09  21.857122  0.084086  4.765159e+09
#
# [250924 rows x 16 columns]

# %%
raw_data.columns
# Out:
# Index(['objID', 'fieldID', 'field', 'ra', 'dec', 'raErr', 'decErr', 'i',
#        'err_i', 'TAI_i', 'u', 'err_u', 'TAI_u', 'g', 'err_g', 'TAI_g'],
#       dtype='object')

# %%
from astropy.time import Time

filters = ['u', 'g', 'i']
columns = ['ra', 'dec', 'fieldID', 'objID', 'raErr', 'decErr', 'obs']
df_list = []
for f in filters:
    df = pd.DataFrame(columns=['obs_id', 'ra', 'dec', 'ra_sigma', 'dec_sigma', 'mag', 'mag_sigma', 'filter', 'observatory_code'])
    
    df['obs_id'] = raw_data['objID'].apply(lambda x: f'{x}_{f}')
    df['exposure_id'] = raw_data['fieldID']
    df['ra'] = raw_data['ra']
    df['ra_sigma'] = raw_data['raErr']
    df['dec'] = raw_data['dec']
    df['dec_sigma'] = raw_data['decErr']
    df['filter'] = f
    df['mag'] = raw_data[f]
    df['mag_sigma'] = raw_data[f'err_{f}']
    df['mjd_utc'] = Time(raw_data[f'TAI_{f}']/(24*3600), scale='tai', format='mjd').utc.mjd
    df['observatory_code'] = '645'
    df_list.append(df)
    
df = pd.concat(df_list, ignore_index=True)
df.sort_values(by=['mjd_utc', 'exposure_id'], ignore_index=True)
# Out:
#                        obs_id        ra        dec  ra_sigma  dec_sigma  \
# 0       1237645876871561298_i  0.000245  -1.034296  0.002277   0.001837
# 1       1237645876871561300_i  0.000173  -0.838730  0.006489   0.005588
# 2       1237645876871561491_i  0.000226  -0.884496  0.039081   0.035090
# 3       1237645876871561233_i  0.030843  -0.906976  0.066555   0.083157
# 4       1237645876871561348_i  0.030787  -0.855554  0.015622   0.013614
# ...                       ...       ...        ...       ...        ...
# 752767  1237680514163737557_g  0.090369  35.842972  0.113184   0.138118
# 752768  1237680514163737566_g  0.095524  35.933415  0.063354   0.079299
# 752769  1237680514163736724_g  0.081007  35.875682  0.003003   0.002971
# 752770  1237680514163737037_g  0.080519  35.790231  0.034364   0.036788
# 752771  1237680514163737552_g  0.081414  35.822182  0.145258   0.097919
#
#               mag  mag_sigma filter observatory_code          exposure_id  \
# 0       16.290249   0.004063      i              645  1237645876871561216
# 1       18.285872   0.010376      i              645  1237645876871561216
# 2       19.574667   0.033383      i              645  1237645876871561216
# 3       20.235672   0.049130      i              645  1237645876871561216
# 4       18.512777   0.012075      i              645  1237645876871561216
# ...           ...        ...    ...              ...                  ...
# 752767  24.643091   0.682343      g              645  1237680514163736576
# 752768  23.246637   0.280273      g              645  1237680514163736576
# 752769  17.761066   0.005441      g              645  1237680514163736576
# 752770  19.106573   0.015812      g              645  1237680514163736576
# 752771  23.221224   0.331977      g              645  1237680514163736576
#
#              mjd_utc
# 0       51075.298600
# 1       51075.298600
# 2       51075.298600
# 3       51075.298715
# 4       51075.298715
# ...              ...
# 752767  55152.297986
# 752768  55152.297986
# 752769  55152.297986
# 752770  55152.297986
# 752771  55152.297986
#
# [752772 rows x 11 columns]

# %%
ras = np.linspace(0, 360, 360 * 10 + 1)
for i in range(len(ras)-1):
    query_by_ra(ras[i], ras[i+1], check_download_integrity=False)
# Out:
# 55.0 55.1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [65], in <cell line: 2>()
#       1 ras = np.linspace(0, 360, 360 * 10 + 1)
#       2 for i in range(len(ras)-1):
# ----> 3     query_by_ra(ras[i], ras[i+1], check_download_integrity=False)
#
# Input In [63], in query_by_ra(ra_start, ra_stop, check_download_integrity)
#      11 print(ra_start, ra_stop)
#      12 query = f"""
#      13         SELECT objID, fieldID, field, ra, dec, raErr, decErr,
#      14         u, err_u, TAI_u,
#    (...)
#      20         WHERE (ra >= {ra_start}) AND (ra < {ra_stop})
#      21         """
# ---> 22 raw_data = SDSS.query_sql(query, timeout=3600, data_release=9).to_pandas()
#      24 #formatted_data = {
#      25 #                    'obs_id':raw_data['objID'].astype(str), # add _filter to tag
#      26 #                    'exposure_id':raw_data['fieldID'].astype(str),
#    (...)
#      35 #                    'observatory_code':'645'
#      36 #                }
#      40 filters = ['u', 'g', 'r', 'i', 'z']
#
# File ~/.conda/envs/precovery_py39/lib/python3.9/site-packages/astroquery/utils/class_or_instance.py:25, in class_or_instance.__get__.<locals>.f(*args, **kwds)
#      23 def f(*args, **kwds):
#      24     if obj is not None:
# ---> 25         return self.fn(obj, *args, **kwds)
#      26     else:
#      27         return self.fn(cls, *args, **kwds)
#
# File ~/.conda/envs/precovery_py39/lib/python3.9/site-packages/astroquery/utils/process_asyncs.py:26, in async_to_sync.<locals>.create_method.<locals>.newmethod(self, *args, **kwargs)
#      22 @class_or_instance
#      23 def newmethod(self, *args, **kwargs):
#      24     verbose = kwargs.pop('verbose', False)
# ---> 26     response = getattr(self, async_method_name)(*args, **kwargs)
#      27     if kwargs.get('get_query_payload') or kwargs.get('field_help'):
#      28         return response
#
# File ~/.conda/envs/precovery_py39/lib/python3.9/site-packages/astroquery/sdss/core.py:483, in SDSSClass.query_sql_async(self, sql_query, timeout, data_release, cache, **kwargs)
#     480     return request_payload
#     482 url = self._get_query_url(data_release)
# --> 483 response = self._request("GET", url, params=request_payload,
#     484                          timeout=timeout, cache=cache)
#     485 return response
#
# File ~/.conda/envs/precovery_py39/lib/python3.9/site-packages/astroquery/query.py:317, in BaseQuery._request(self, method, url, params, data, headers, files, save, savedir, timeout, cache, stream, auth, continuation, verify, allow_redirects, json, return_response_on_save)
#     315     response = query.from_cache(self.cache_location)
#     316     if not response:
# --> 317         response = query.request(self._session,
#     318                                  self.cache_location,
#     319                                  stream=stream,
#     320                                  auth=auth,
#     321                                  allow_redirects=allow_redirects,
#     322                                  verify=verify,
#     323                                  json=json)
#     324         to_cache(response, query.request_file(self.cache_location))
#     325 self._last_query = query
#
# File ~/.conda/envs/precovery_py39/lib/python3.9/site-packages/astroquery/query.py:71, in AstroQuery.request(self, session, cache_location, stream, auth, verify, allow_redirects, json)
#      68 def request(self, session, cache_location=None, stream=False,
#      69             auth=None, verify=True, allow_redirects=True,
#      70             json=None):
# ---> 71     return session.request(self.method, self.url, params=self.params,
#      72                            data=self.data, headers=self.headers,
#      73                            files=self.files, timeout=self.timeout,
#      74                            stream=stream, auth=auth, verify=verify,
#      75                            allow_redirects=allow_redirects,
#      76                            json=json)
#
# File ~/.conda/envs/precovery_py39/lib/python3.9/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~/.conda/envs/precovery_py39/lib/python3.9/site-packages/requests/sessions.py:652, in Session.send(self, request, **kwargs)
#     649 r.elapsed = timedelta(seconds=elapsed)
#     651 # Response manipulation hooks
# --> 652 r = dispatch_hook('response', hooks, r, **kwargs)
#     654 # Persist cookies
#     655 if r.history:
#     656
#     657     # If the hooks create history then we want those cookies too
#
# File ~/.conda/envs/precovery_py39/lib/python3.9/site-packages/requests/hooks.py:31, in dispatch_hook(key, hooks, hook_data, **kwargs)
#      29     hooks = [hooks]
#      30 for hook in hooks:
# ---> 31     _hook_data = hook(hook_data, **kwargs)
#      32     if _hook_data is not None:
#      33         hook_data = _hook_data
#
# File ~/.conda/envs/precovery_py39/lib/python3.9/site-packages/astroquery/query.py:218, in BaseQuery._response_hook(self, response, *args, **kwargs)
#     206     response_log = textwrap.indent(
#     207         f"-----------------------------------------\n"
#     208         f"{response.status_code} {response.reason} {response.url}\n"
#     209         f"{response_hdrs}\n"
#     210         "Streaming Data\n"
#     211         f"-----------------------------------------", '\t')
#     212 else:
#     213     response_log = textwrap.indent(
#     214         f"-----------------------------------------\n"
#     215         f"{response.status_code} {response.reason} {response.url}\n"
#     216         f"{response_hdrs}\n"
#     217         f"\n"
# --> 218         f"{response.text}\n"
#     219         f"-----------------------------------------", '\t')
#     220 log.log(5, f"HTTP response\n{response_log}")
#
# File ~/.conda/envs/precovery_py39/lib/python3.9/site-packages/requests/models.py:862, in Response.text(self)
#     859 content = None
#     860 encoding = self.encoding
# --> 862 if not self.content:
#     863     return str('')
#     865 # Fallback to auto-detected encoding.
#
# File ~/.conda/envs/precovery_py39/lib/python3.9/site-packages/requests/models.py:838, in Response.content(self)
#     836         self._content = None
#     837     else:
# --> 838         self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     840 self._content_consumed = True
#     841 # don't need to release the connection; that's been handled by urllib3
#     842 # since we exhausted the data.
#
# File ~/.conda/envs/precovery_py39/lib/python3.9/site-packages/requests/models.py:760, in Response.iter_content.<locals>.generate()
#     758 if hasattr(self.raw, 'stream'):
#     759     try:
# --> 760         for chunk in self.raw.stream(chunk_size, decode_content=True):
#     761             yield chunk
#     762     except ProtocolError as e:
#
# File ~/.conda/envs/precovery_py39/lib/python3.9/site-packages/urllib3/response.py:579, in HTTPResponse.stream(self, amt, decode_content)
#     577 else:
#     578     while not is_fp_closed(self._fp):
# --> 579         data = self.read(amt=amt, decode_content=decode_content)
#     581         if data:
#     582             yield data
#
# File ~/.conda/envs/precovery_py39/lib/python3.9/site-packages/urllib3/response.py:522, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     520 else:
#     521     cache_content = False
# --> 522     data = self._fp.read(amt) if not fp_closed else b""
#     523     if (
#     524         amt != 0 and not data
#     525     ):  # Platform-specific: Buggy versions of Python.
#    (...)
#     531         # not properly close the connection in all cases. There is
#     532         # no harm in redundantly calling close.
#     533         self._fp.close()
#
# File ~/.conda/envs/precovery_py39/lib/python3.9/http/client.py:463, in HTTPResponse.read(self, amt)
#     460 if amt is not None:
#     461     # Amount is given, implement using readinto
#     462     b = bytearray(amt)
# --> 463     n = self.readinto(b)
#     464     return memoryview(b)[:n].tobytes()
#     465 else:
#     466     # Amount is not given (unbounded read) so we must check self.length
#     467     # and self.chunked
#
# File ~/.conda/envs/precovery_py39/lib/python3.9/http/client.py:507, in HTTPResponse.readinto(self, b)
#     502         b = memoryview(b)[0:self.length]
#     504 # we do not use _safe_read() here because this may be a .will_close
#     505 # connection, and the user is reading more bytes than will be provided
#     506 # (for example, reading in 1k chunks)
# --> 507 n = self.fp.readinto(b)
#     508 if not n and b:
#     509     # Ideally, we would raise IncompleteRead if the content-length
#     510     # wasn't satisfied, but it might break compatibility.
#     511     self._close_conn()
#
# File ~/.conda/envs/precovery_py39/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#times taken from casjobs query
TAI_i_min = 4412900195.78825
TAI_i_max = 4765233246.05795

mjd_min = TAI_i_min/(24*3600)
mjd_max = TAI_i_max/(24*3600)

mjd_min, mjd_max
# Out:
# (51075.23374754919, 55153.162570115164)

# %%
min_max = SDSS.query_sql_async("SELECT min(TAI_i) as min_TAI_i, max(TAI_i) as max_TAI_i FROM PhotoObj WHERE TAI_i != -9999", 
               timeout = 3600,
               data_release=9)

"""SELECT
    team_id,
    MAX(salary)
    FROM
    workers
    GROUP BY team_id
"""
min_max
# Out:
# <Response [200]>

# %%
min_max["min_TAI_i"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [78], in <cell line: 1>()
# ----> 1 min_max["min_TAI_i"]
#
# TypeError: 'Response' object is not subscriptable

# %%
import glob
import multiprocessing as mp
from astropy.time import Time

window_size = 31
window_starts = np.arange(
    np.floor(mjd_min), 
    np.ceil(mjd_max), 
    window_size
)

observation_files = glob.glob(os.path.join(DATA_DIR, '*'))

# %%
def processWindow(window_file_name, observations):
    if len(observations) > 0:
        observations.to_hdf(
            window_file_name, 
            key="data", 
            mode="a", 
            append=True, 
            min_itemsize={'obs_id': 40, 'exposure_id': 40, 'filter' : 1, 'observatory_code': 1},
        )
    return

# %%
#joachim's code - sort csv file entries into months and save them as hdf5 files - windows

def convert_to_hdf5(observation_files, test=False):
    os.nice(10)

    pool = mp.Pool(10)

    observation_files_completed = np.array([])
    for i, observation_file in enumerate(observation_files):
        observations = pd.read_csv(observation_file, index_col=False, 
                                   dtype={'observatory_code': str, 'obs_id': str, 'exposure_id': str})

        windows = []
        window_file_names = []
        for window_start in window_starts:

            window_end = window_start + window_size
            start_isot = Time(window_start, scale="utc", format="mjd").isot.split("T")[0]
            end_isot = Time(window_end, scale="utc", format="mjd").isot.split("T")[0]

            if test:
                window_file_name = os.path.join(DATA_DIR, "hdf5_test", f"sdss_dr9_observations_{start_isot}_{end_isot}.h5")
            else:
                window_file_name = os.path.join(DATA_DIR, "hdf5", f"sdss_dr9_observations_{start_isot}_{end_isot}.h5")
            window_file_names.append(window_file_name)

            observations_window = observations[(observations["mjd_utc"] >= window_start) & (observations["mjd_utc"] < window_end)]
            windows.append(observations_window)

        pool.starmap(
            processWindow,
            zip(window_file_names, windows)
        )

        observation_files_completed = np.concatenate([observation_files_completed, np.array([observation_file])])
        np.savetxt("files_processed.txt", observation_files_completed, delimiter="\n", fmt="%s")

        if (i + 1) % 20 == 0:
            print(f"Processed {i + 1} observations files.")

    pool.close()

# %%
OLD_DATA_DIR = '/astro/store/epyc3/data3/adam_datasets/sdss_dr9'
sample_obs_file = [os.path.join(DATA_DIR, f"sdss_dr9_observations_{ra_start:06.2f}_{ra_stop:06.2f}_all.csv")]
convert_to_hdf5(sample_obs_file, test=True)
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/astro/users/ejgl/.conda/envs/precovery_py39/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/astro/users/ejgl/.conda/envs/precovery_py39/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_123948/1134819843.py", line 3, in processWindow
#     observations.to_hdf(
#   File "/astro/users/ejgl/.conda/envs/precovery_py39/lib/python3.9/site-packages/pandas/core/generic.py", line 2763, in to_hdf
#     pytables.to_hdf(
#   File "/astro/users/ejgl/.conda/envs/precovery_py39/lib/python3.9/site-packages/pandas/io/pytables.py", line 314, in to_hdf
#     f(store)
#   File "/astro/users/ejgl/.conda/envs/precovery_py39/lib/python3.9/site-packages/pandas/io/pytables.py", line 282, in <lambda>
#     f = lambda store: store.append(
#   File "/astro/users/ejgl/.conda/envs/precovery_py39/lib/python3.9/site-packages/pandas/io/pytables.py", line 1262, in append
#     self._write_to_group(
#   File "/astro/users/ejgl/.conda/envs/precovery_py39/lib/python3.9/site-packages/pandas/io/pytables.py", line 1772, in _write_to_group
#     s.write(
#   File "/astro/users/ejgl/.conda/envs/precovery_py39/lib/python3.9/site-packages/pandas/io/pytables.py", line 4299, in write
#     table = self._create_axes(
#   File "/astro/users/ejgl/.conda/envs/precovery_py39/lib/python3.9/site-packages/pandas/io/pytables.py", line 4018, in _create_axes
#     new_table.validate(self)
#   File "/astro/users/ejgl/.conda/envs/precovery_py39/lib/python3.9/site-packages/pandas/io/pytables.py", line 3360, in validate
#     raise ValueError(
# ValueError: invalid combination of [values_axes] on appending data [name->obs_id,cname->obs_id,dtype->bytes320,kind->string,shape->(1, 18400)] vs current table [name->obs_id,cname->obs_id,dtype->int64,kind->integer,shape->None]
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [62], in <cell line: 3>()
#       1 OLD_DATA_DIR = '/astro/store/epyc3/data3/adam_datasets/sdss_dr9'
#       2 sample_obs_file = [os.path.join(OLD_DATA_DIR, f"sdss_dr9_observations_{ra_start:06.2f}_{ra_stop:06.2f}_all.csv")]
# ----> 3 convert_to_hdf5(sample_obs_file, test=True)
#
# Input In [61], in convert_to_hdf5(observation_files, test)
#      27     observations_window = observations[(observations["mjd_utc"] >= window_start) & (observations["mjd_utc"] < window_end)]
#      28     windows.append(observations_window)
# ---> 30 pool.starmap(
#      31     processWindow,
#      32     zip(window_file_names, windows)
#      33 )
#      35 observation_files_completed = np.concatenate([observation_files_completed, np.array([observation_file])])
#      36 np.savetxt("files_processed.txt", observation_files_completed, delimiter="\n", fmt="%s")
#
# File ~/.conda/envs/precovery_py39/lib/python3.9/multiprocessing/pool.py:372, in Pool.starmap(self, func, iterable, chunksize)
#     366 def starmap(self, func, iterable, chunksize=None):
#     367     '''
#     368     Like `map()` method but the elements of the `iterable` are expected to
#     369     be iterables as well and will be unpacked as arguments. Hence
#     370     `func` and (a, b) becomes func(a, b).
#     371     '''
# --> 372     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File ~/.conda/envs/precovery_py39/lib/python3.9/multiprocessing/pool.py:771, in ApplyResult.get(self, timeout)
#     769     return self._value
#     770 else:
# --> 771     raise self._value
#
# ValueError: invalid combination of [values_axes] on appending data [name->obs_id,cname->obs_id,dtype->bytes320,kind->string,shape->(1, 18400)] vs current table [name->obs_id,cname->obs_id,dtype->int64,kind->integer,shape->None]

# %%
TEST_DIR = '/astro/store/epyc3/data3/adam_datasets/sdss_dr9/test'
#obs_files = glob.glob(os.path.join(DATA_DIR, '*'))
test_obs_files = glob.glob(os.path.join(TEST_DIR, '*'))
convert_to_hdf5(test_obs_files, test=True)
# Out:
# Processed 20 observations files.

# %%
#run index_observations py script (slide 7 of precovery)
#bug in precovery/sourcecatalog.py - line 78 - must convert to string to use encode()
from astropy.time import Time
t = Time(2459261.291142335476, format='jd', scale='tdb')
t.tt.mjd
# Out:
# 59260.79114232246

# %%
from precovery.orbit import Orbit, EpochTimescale
from precovery import precover

orbit = Orbit.keplerian(
    2202930,
    2.719500955919493,
    0.1298610598232667,
    4.562907166251742,
    346.1459277333923,
    7.61979564713161,
    118.5024332609956,
    59260.79114232246,
    EpochTimescale.TT, #data is in scale TDB (barycentric dynamical time)
    16.82,
    .15 #photometric slope parameter - what to put in?
)

orbit.compute_ephemeris('645', [51075.299190])
# Out:
# WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01).
#
#
# WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01).
#
#
# WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01).
# 645
# [51075.29919]

# %%
from precovery.orbit import Orbit, EpochTimescale
from precovery import precover

DB_DIR = "/astro/store/epyc3/data3/adam_datasets/sdss_dr9/precovery_results_2"

orbit = Orbit.keplerian(
    2202930,
    2.719500955919493,
    0.1298610598232667,
    4.562907166251742,
    346.1459277333923,
    7.61979564713161,
    118.5024332609956,
    59260.79114232246,
    EpochTimescale.TT, #data is in scale TDB (barycentric dynamical time)
    16.82,
    .15 #photometric slope parameter - what to put in?
)


results = precover(orbit, DB_DIR, tolerance=1/3600)
# Out:
# b'\x85\x02\x00\x00\x00\x00\x00\x00'
# [51075.29895833333, 51082.29895833333, 51460.29895833333, 51467.29895833333, 51789.29895833333, 51810.29895833333, 51817.29895833333, 51866.29895833333, 51880.29895833333, 52146.29895833333, 52167.29895833333, 52195.29895833333, 52223.29895833333, 52230.29895833333, 52251.29895833333, 52524.29895833333, 52552.29895833333, 52559.29895833333, 52580.29895833333, 52587.29895833333, 52909.29895833333, 52930.29895833333, 52937.29895833333, 52958.29895833333, 52965.29895833333, 53259.29895833333, 53266.29895833333, 53273.29895833333, 53287.29895833333, 53294.29895833333, 53315.29895833333, 53350.29895833333, 53623.29895833333, 53637.29895833333, 53644.29895833333, 53994.29895833333, 54008.29895833333, 54715.29895833333, 54743.29895833333, 54750.29895833333, 54764.29895833333, 54771.29895833333, 54792.29895833333, 54827.29895833333, 54848.29895833333, 54855.29895833333, 54862.29895833333, 55100.29895833333, 55121.29895833333, 55149.29895833333]
# ***ERROR*** 20 Sep 2022 22:18:21UTC (Observatories / getPosition) Code b'\x85\x02\x00\x00\x00\x00\x00\x00' does not refer to any observatory listed in /astro/users/ejgl/.conda/envs/precovery_py39/share/openorb/OBSCODE.dat
# ***ERROR*** 20 Sep 2022 22:18:21UTC (Observatories / getGeocentricObservatoryCCoord) TRACE BACK (15)
# ***ERROR*** 20 Sep 2022 22:18:21UTC (Observatories / getObservatoryCCoord) TRACE BACK (15)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [2], in <cell line: 21>()
#       4 DB_DIR = "/astro/store/epyc3/data3/adam_datasets/sdss_dr9/precovery_results"
#       6 orbit = Orbit.keplerian(
#       7     2202930,
#       8     2.719500955919493,
#    (...)
#      17     .15 #photometric slope parameter - what to put in?
#      18 )
# ---> 21 results = precover(orbit, DB_DIR, tolerance=1/3600)
#
# File /nvme/users/ejgl/precovery/precovery/main.py:103, in precover(orbit, database_directory, tolerance, max_matches, start_mjd, end_mjd, window_size, include_frame_candidates)
#      58 """
#      59 Connect to database directory and run precovery for the input orbit.
#      60
#    (...)
#      95     found within the angular tolerance.
#      96 """
#      97 precovery_db = PrecoveryDatabase.from_dir(
#      98     database_directory,
#      99     create=False,
#     100     mode="r"
#     101 )
# --> 103 candidates = [
#     104     c for c in precovery_db.precover(
#     105         orbit,
#     106         tolerance=tolerance,
#     107         max_matches=max_matches,
#     108         start_mjd=start_mjd,
#     109         end_mjd=end_mjd,
#     110         window_size=window_size,
#     111         include_frame_candidates=include_frame_candidates
#     112     )
#     113 ]
#     115 df = pd.DataFrame(_candidates_to_dict(candidates))
#     116 df.loc[:, "observation_id"] = df.loc[:, "observation_id"].astype(str)
#
# File /nvme/users/ejgl/precovery/precovery/main.py:103, in <listcomp>(.0)
#      58 """
#      59 Connect to database directory and run precovery for the input orbit.
#      60
#    (...)
#      95     found within the angular tolerance.
#      96 """
#      97 precovery_db = PrecoveryDatabase.from_dir(
#      98     database_directory,
#      99     create=False,
#     100     mode="r"
#     101 )
# --> 103 candidates = [
#     104     c for c in precovery_db.precover(
#     105         orbit,
#     106         tolerance=tolerance,
#     107         max_matches=max_matches,
#     108         start_mjd=start_mjd,
#     109         end_mjd=end_mjd,
#     110         window_size=window_size,
#     111         include_frame_candidates=include_frame_candidates
#     112     )
#     113 ]
#     115 df = pd.DataFrame(_candidates_to_dict(candidates))
#     116 df.loc[:, "observation_id"] = df.loc[:, "observation_id"].astype(str)
#
# File /nvme/users/ejgl/precovery/precovery/precovery_db.py:201, in PrecoveryDatabase.precover(self, orbit, tolerance, max_matches, start_mjd, end_mjd, window_size, include_frame_candidates)
#     190 mjds = [window[0] for window in obs_windows]
#     191 matches = self._check_windows(
#     192     mjds,
#     193     obscode,
#    (...)
#     199     include_frame_candidates=include_frame_candidates
#     200 )
# --> 201 for result in matches:
#     202     yield result
#     203     n += 1
#
# File /nvme/users/ejgl/precovery/precovery/precovery_db.py:225, in PrecoveryDatabase._check_windows(self, window_midpoints, obscode, orbit, tolerance, start_mjd, end_mjd, window_size, include_frame_candidates)
#     222 orbit_propagated = orbit.propagate(window_midpoints, PropagationIntegrator.N_BODY)
#     224 # Calculate the location of the orbit on the sky with n-body propagation
# --> 225 window_ephems = orbit.compute_ephemeris(obscode, window_midpoints, PropagationIntegrator.N_BODY)
#     226 window_healpixels = radec_to_healpixel(
#     227     np.array([w.ra for w in window_ephems]),
#     228     np.array([w.dec for w in window_ephems]),
#     229     self.frames.healpix_nside,
#     230 ).astype(int)
#     232 # Using the propagated orbits, check each window. Propagate the orbit from the center of
#     233 # window using 2-body to find any HealpixFrames where a detection could have occured
#
# File /nvme/users/ejgl/precovery/precovery/orbit.py:255, in Orbit.compute_ephemeris(self, obscode, epochs, method)
#     247 eph, err = pyoorb.pyoorb.oorb_ephemeris_basic(
#     248     in_orbits=self._state_vector,
#     249     in_obscode=str(obscode).encode(),
#     250     in_date_ephems=epochs_array,
#     251     in_dynmodel=dynmodel,
#     252 )
#     253 # print(epochs_array.shape)
#     254 # print(eph.shape)
# --> 255 assert err == 0, f"Error: {err}"
#     256 return [Ephemeris(eph[0, i, :]) for i in range(epochs_array.shape[0])]
#
# AssertionError: Error: 36

# %%
#import sqlite3 as sql

#con = sql.connect(DB_DIR + '/index.db')

# %%
#con.execute('CREATE index fast_query on frames (mjd, healpixel, obscode)')

# %%
#frames = pd.read_sql('SELECT * FROM frames', con)

# %%
#frames
# Out:
#               id dataset_id                              obscode  \
# 0              1   SDSS_DR9  b'\x85\x02\x00\x00\x00\x00\x00\x00'
# 1              2   SDSS_DR9  b'\x85\x02\x00\x00\x00\x00\x00\x00'
# 2              3   SDSS_DR9  b'\x85\x02\x00\x00\x00\x00\x00\x00'
# 3              4   SDSS_DR9  b'\x85\x02\x00\x00\x00\x00\x00\x00'
# 4              5   SDSS_DR9  b'\x85\x02\x00\x00\x00\x00\x00\x00'
# ...          ...        ...                                  ...
# 2356951  2356952   SDSS_DR9  b'\x85\x02\x00\x00\x00\x00\x00\x00'
# 2356952  2356953   SDSS_DR9  b'\x85\x02\x00\x00\x00\x00\x00\x00'
# 2356953  2356954   SDSS_DR9  b'\x85\x02\x00\x00\x00\x00\x00\x00'
# 2356954  2356955   SDSS_DR9  b'\x85\x02\x00\x00\x00\x00\x00\x00'
# 2356955  2356956   SDSS_DR9  b'\x85\x02\x00\x00\x00\x00\x00\x00'
#
#                            exposure_id filter           mjd  healpixel  \
# 0           b'\x00\x00\xa8 ^\x00-\x11'      i  51075.299190       4351
# 1           b'\x00\x00\xa8@^\x00-\x11'      i  51075.299190       4351
# 2           b'\x00\x00\xa8`^\x00-\x11'      i  51075.299190       4351
# 3           b'\x00\x00\xa8`^\x00-\x11'      i  51075.299190       4522
# 4        b'\x00\x00\xa8\x80^\x00-\x11'      i  51075.299190       4864
# ...                                ...    ...           ...        ...
# 2356951     b'\x00\x005@\xde\x1f-\x11'      i  55152.301620       5108
# 2356952     b'\x00\x005`\xde\x1f-\x11'      i  55152.301620       5108
# 2356953  b'\x00\x005\x80\xde\x1f-\x11'      i  55152.301620       5108
# 2356954  b'\x00\x005\xa0\xde\x1f-\x11'      i  55152.301620       5108
# 2356955  b'\x00\x005\xc0\xde\x1f-\x11'      i  55152.301736       5111
#
#                      data_uri  data_offset  data_length
# 0        frames_00000000.data            0          355
# 1        frames_00000000.data          355          355
# 2        frames_00000000.data          710          568
# 3        frames_00000000.data         1278           71
# 4        frames_00000000.data         1349          213
# ...                       ...          ...          ...
# 2356951  frames_00000000.data    468735610           71
# 2356952  frames_00000000.data    468735681          142
# 2356953  frames_00000000.data    468735823           71
# 2356954  frames_00000000.data    468735894           71
# 2356955  frames_00000000.data    468735965           71
#
# [2356956 rows x 10 columns]

# %%
hd_df = pd.read_hdf('/astro/users/ejgl/epyc/data3/adam_datasets/sdss_dr9/hdf5/sdss_dr9_observations_1998-09-19_1998-10-20.h5')
hd_df
# Out:
#                      obs_id          exposure_id       mjd_utc        ra  \
# 0       1237645876871561542  1237645876871561216  51075.299190  0.044252
# 1       1237645876871561543  1237645876871561216  51075.299190  0.045429
# 2       1237645876871561544  1237645876871561216  51075.299190  0.045675
# 3       1237645876871561715  1237645876871561216  51075.299190  0.044419
# 4       1237645876871561884  1237645876871561216  51075.299190  0.045444
# ...                     ...                  ...           ...       ...
# 240726  1237645879557095775  1237645879557095424  51075.306481  2.673712
# 240727  1237646010010567116  1237646010010566656  51081.290046  2.673732
# 240728  1237646011084309063  1237646011084308480  51081.290046  2.673707
# 240729  1237646011621180043  1237646011621179392  51081.290046  2.673600
# 240730  1237646012694921761  1237646012694921216  51081.290046  2.673696
#
#              dec  ra_sigma  dec_sigma filter        mag  mag_sigma  \
# 0      -0.937640  0.146648   0.136783      i  20.067837   0.081154
# 1      -0.872684  0.065231   0.057989      i  20.505260   0.063039
# 2      -0.949524  0.156135   0.097594      i  21.049526   0.125765
# 3      -0.998018  0.096438   0.063111      i  20.161160   0.067760
# 4      -0.978974  0.300121   0.218308      i  21.821657   0.324532
# ...          ...       ...        ...    ...        ...        ...
# 240726  1.117745  0.317605   0.181244      i  21.995596   0.341091
# 240727 -1.061100  0.104356   0.074070      i  20.147598   0.068207
# 240728 -0.287716  0.107323   0.133157      i  21.026785   0.105682
# 240729  0.183348  0.219226   0.174383      i  21.472067   0.164109
# 240730  0.989767  0.235646   0.232693      i  21.263554   0.163339
#
#         observatory_code
# 0                    645
# 1                    645
# 2                    645
# 3                    645
# 4                    645
# ...                  ...
# 240726               645
# 240727               645
# 240728               645
# 240729               645
# 240730               645
#
# [107473 rows x 11 columns]

# %%
# run for observatory_code, exposure_id, observation_id
hd_df['observatory_code'] = hd_df['observatory_code'].astype(str)
hd_df['exposure_id'] = hd_df['exposure_id'].astype(str)
hd_df['obs_id'] = hd_df['obs_id'].astype(str)

# %%
HDF_DIR = '/astro/users/ejgl/epyc/data3/adam_datasets/sdss_dr9/hdf5'

hdf5_files = glob.glob(os.path.join(HDF_DIR, '*'))
for file in hdf5_files:
    hd_df = pd.read_hdf(file)
    hd_df['observatory_code'] = hd_df['observatory_code'].astype(str)
    hd_df['exposure_id'] = hd_df['exposure_id'].astype(str)
    hd_df['obs_id'] = hd_df['obs_id'].astype(str)
    hd_df.to_hdf(file, key='data')

# %%
hd_df = pd.read_hdf('/astro/users/ejgl/epyc/data3/adam_datasets/sdss_dr9/hdf5/sdss_dr9_observations_1998-09-19_1998-10-20.h5')
hd_df['obs_id'].dtype
# Out:
# dtype('O')

# %%
con.close()
